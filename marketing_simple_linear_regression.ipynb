# %% [markdown]
# # Simple Linear Regression – Marketing Sales Prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import scipy.stats as stats

# %%
df=pd.read_csv('85334965-5736-457a-b8d4-a077e6872f84.csv')
df.head()

# %%
df.shape
df.describe()

# %%
sns.scatterplot(data=df,x='TV',y='Sales')
plt.show()

# %%
df.hist(figsize=(8,6))
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
model=smf.ols('Sales ~ TV',data=df).fit()
print(model.summary())

# %%
residuals=model.resid
fitted=model.fittedvalues
sns.scatterplot(x=fitted,y=residuals)
plt.axhline(0)
plt.show()

# %%
stats.probplot(residuals,dist='norm',plot=plt)
plt.show()

# %% [markdown]
# Interpret R-squared, p-values and coefficient in markdown after running.
